# %%
import pandas as pd
import numpy as np

data = pd.read_csv("original/research_training_set.csv")

# %%
data.dtypes
# Out:
# review_id                   object
# user_id                     object
# business_id                 object
# stars                        int64
# useful                       int64
# funny                        int64
# cool                         int64
# text                        object
# date                        object
# token_count_nltk             int64
# user_name                   object
# user_review_count            int64
# user_yelping_since          object
# user_useful                  int64
# user_funny                   int64
# user_cool                    int64
# user_elite                  object
# user_friends                object
# user_fans                    int64
# user_average_stars         float64
# user_compliment_hot          int64
# user_compliment_more         int64
# user_compliment_profile      int64
# user_compliment_cute         int64
# user_compliment_list         int64
# user_compliment_note         int64
# user_compliment_plain        int64
# ...

# %%
set(data['stars'])
# Out:
# {1, 2, 3, 4, 5}

# %%
data['stars'].value_counts()
# Out:
# stars
# 4    4364
# 5    4132
# 3    1829
# 2     632
# 1     239
# Name: count, dtype: int64

# %%
from pathlib import Path
import nbformat

def load_notebook(notebook_path):
    with open(notebook_path, 'r', encoding='utf-8') as f:
        nb = nbformat.read(f, as_version=4)
    code_cells = [cell.source for cell in nb.cells if cell.cell_type == 'code']
    exec('\n'.join(code_cells), globals())

# import written function and variable

parent_directory = Path('../')
data_preprocessing_utils_path = parent_directory / 'data_preprocessing_utils.ipynb'
experiment_related_utils_path = parent_directory / 'experiment_related_utils.ipynb'
load_notebook(data_preprocessing_utils_path)
load_notebook(experiment_related_utils_path)

# %%
experiment_model_best_mse_run_ids = {
    "original": {
        "bbs": {
            "FM": {
                "MSE": "6b5c706cb981494bba1ebab80ddbd1e7",
                "MAE": "cef20684dc4c4dc89fc0cc792a8330c1",
            },
            "AutoInt": {
                "MSE": "ee752775264c421bb2360a6fa637ceba",
                "MAE": "1f2adb03c71540ca8252905e08a84f02",
            },
            "MLP": {
                "MSE": "c36e962ce27b479a8249a677c916da8a",
                "MAE": "b383b5f87ce842f0949c8c3701d63845",
            },
            "XGBoost": {
                "MSE": "a2f70c7f743a4ceb874f63f324a86fc2",
                "MAE": "cabce1fc1e904fa2867aac85ed9493b2",
            },
            "RandomForest": {
                "MSE": '05b4cf085b634fc3be0dab8f5fa1dfa7',
                "MAE": "c9ca4c50d64d43078ede9bedb1ffd1d9",
            }
        },
        "robbs": {
            "FM": {
                "MSE": "d3356714e7de43edaf1f9fdeaddb544a",
                "MAE": "d75bd83a41aa40a3a5523610f4b6c3b2",
            },
            "AutoInt": {
                "MSE": "26e422d1ed1b4b0c9983833a95862460",
                "MAE": "73dac0cb441a41e5950974b3967f3960",
            },
            "MLP": {
                "MSE": "f9ef4761b4614ad1bea9446489b465d3",
                "MAE": "ae0033394d044a43bf1cbe0c51bdcc77",
            },
            "XGBoost": {
                "MSE": '6c1402ab0cc54cbb8601ca7c0748ac50',
                "MAE": "0ad322af6a6e4c2e98c870a2df4c44ba",
            },
            "RandomForest": {
                "MSE": "786d4b5dff80456992d83184a7250491",
                "MAE": '46eb55a2e3bd40cda55bfaab724b72e0',
            }
        }
    },
    "gpt_prompt_v1": {
        "bbs": {
            "FM": {
                "MSE": "e5424458d6904175a54c887f2eb0c06a",
                "MAE": "c17444cd22eb4e169f883247769b6f85",
            },
            "AutoInt": {
                "MSE": 'f549a2385da1484baf9e85550272aebf',
                "MAE": "95b67957960c49f4aa7aa0a3dc9c5ec4",
            },
            "MLP": {
                "MSE": "3ab241efbbf748ada8bc5755e62d66ce",
                "MAE": "ee06bcae241c4e6e850847d78aca1643",
            },
            "XGBoost": {
                "MSE": "b68b4d5d07884fd189586d9237a6dd43",
                "MAE": 'd206c8bd7ef94addb70c581c9c6a60ed',
            },
            "RandomForest": {
                "MSE": "6a13e4b410fd4ae9aa156461c5da4174",
                "MAE": "f3b104cd543340ea86cef2c9b850b768",
            }
        },
        "robbs": {
            "FM": {
                "MSE": '0676fd63cd8a40c0ba743ac6a8c9efbc',
                "MAE": "77e1432d23a04d579f96035b0a36366b",
            },
            "AutoInt": {
                "MSE": "38c54cfccb2b42fd805a424836f20fc9",
                "MAE": "d8f448fd0e7543ae80d2041a4fba03df",
            },
            "MLP": {
                "MSE": "251c8fae2cb5482790b04d8543bed98e",
                "MAE": "3f3368daa5f3449488d5a46cddd00f39",
            },
            "XGBoost": {
                "MSE": "e0f1d15988b84a748eda930472c59121",
                "MAE": "a743337252184a0fa67011f8992e9b85",
            },
            "RandomForest": {
                "MSE": "c205b83dfb6f4075a30f0dec4b5cb3f6",
                "MAE": "30cd73fb027e40bc81e8e47eacd651d4",
            }
        }
    },
    "gpt_prompt_v3": {
        "bbs": {
            "FM": {
                "MSE": "50c55e97b91045b3bd8023dda47a0811",
                "MAE": "134798a07421495da76c82c93f11bace",
            },
            "AutoInt": {
                "MSE": "b39f26c08ae74e24bee05189c648189b",
                "MAE": "c43f3e4e03f748e9956ad5fcd6a4a421",
            },
            "MLP": {
                "MSE": "58f331fdc07048cca67aff690cc655ba",
                "MAE": "5e81939692a64394a1ce2830cca17c7c",
            },
            "XGBoost": {
                "MSE": '976926eab6ad4085ab06667b68b2b2fd',
                "MAE": 'e7c470694b6f4f3ba61a874e15f8b560',
            },
            "RandomForest": {
                "MSE": "3535593136c64dc2bdb7bbb5bcff1112",
                "MAE": "e35ee1cbab504149b41be6a30e709221",
            }
        },
        "robbs": {
            "FM": {
                "MSE": "3daef931877a442297f25484776f9833",
                "MAE": "c147ebd8777b447f8c1fb7887f762d4f",
            },
            "AutoInt": {
                "MSE": "9c25cd7228b94cf6b818e908788b2bbf",
                "MAE": "37e5af9d5218460b99a6bf59a3d3b96c",
            },
            "MLP": {
                "MSE": "7ecd367d90dc461d8d2a67f4162d96ef",
                "MAE": "d55d5ab0a1da45d888ea9db33b102ee2",
            },
            "XGBoost": {
                "MSE": "8093819e77bf4879aa9b8b2eea1a9926",
                "MAE": "c91339ccadf2456988d9e52f71d0df84",
            },
            "RandomForest": {
                "MSE": "23396bfa7d804c0da4e3df9dc97e0c7f",
                "MAE": "ea33147456f74dadb35675b9ed304e29",
            }
        }
    },
    "original_gpt_prompt_v1": {
        "bbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        },
        "robbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        }
    },
    "original_gpt_prompt_v3": {
        "bbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        },
        "robbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        }
    },
    "gpt_prompt_v1_gpt_prompt_v3": {
        "bbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        },
        "robbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        }
    },
    "original_gpt_prompt_v1_gpt_prompt_v3": {
        "bbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        },
        "robbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        }
    },
    "concat_ori_gpt_prompt_v1": {
        "bbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        },
        "robbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        }
    },
    "concat_ori_gpt_prompt_v3": {
        "bbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        },
        "robbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        }
    },
    "concat_gpt_prompt_v1_gpt_prompt_v3": {
        "bbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        },
        "robbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        }
    },
    "concat_ori_gpt_prompt_v1_gpt_prompt_v3": {
        "bbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        },
        "robbs": {
            "FM": {
                "MSE": 0,
                "MAE": 0,
            },
            "AutoInt": {
                "MSE": 0,
                "MAE": 0,
            },
            "MLP": {
                "MSE": 0,
                "MAE": 0,
            },
            "XGBoost": {
                "MSE": 0,
                "MAE": 0,
            },
            "RandomForest": {
                "MSE": 0,
                "MAE": 0,
            }
        }
    }
}

# %%
results = inspect_stars_performance(experiment_model_best_mse_run_ids, task_type="regression")
